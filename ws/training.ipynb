# %% [markdown]
# ## Ray startup

# %%
import ray

ray.shutdown()
ray.init(ignore_reinit_error=True, num_cpus=10, num_gpus=1.0)
# print("Dashboard URL: http://{}".format( ray.get_webui_url()))
# Out:
# 2023-05-19 09:03:18,780	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.10.0', ray_version='2.1.0', ray_commit='be49bde7ee4f6adb3f8710aee0665c27f9f0bb62', address_info={'node_ip_address': '149.156.105.73', 'raylet_ip_address': '149.156.105.73', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2023-05-19_09-03-18_223799_1399484/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2023-05-19_09-03-18_223799_1399484/sockets/raylet', 'webui_url': '127.0.0.1:8265', 'session_dir': '/tmp/ray/session_2023-05-19_09-03-18_223799_1399484', 'metrics_export_port': 49452, 'gcs_address': '149.156.105.73:61036', 'address': '149.156.105.73:61036', 'dashboard_agent_listen_port': 52365, 'node_id': 'ba4f36dc707338fb8b0fd4940b0d4dea7cbe80abf5e7ece2624221ea'})

# %% [markdown]
# ## Registering envs for training

# %%
import gym
from ray.rllib.env.wrappers.dm_control_wrapper import DMCEnv
from ray.tune.registry import register_env
from dm_control.suite import ALL_TASKS, BENCHMARKING, EXTRA

# %%
from_pixels = False
height = 64
width = 64
frame_skip = 2
channels_first = True
max_horizon = 1000  # dosen't work

DEFAULT_ENVS_REGISTRY = {}
for env, task in BENCHMARKING:
    env_task_name = f"{env}-{task}"
    print(env_task_name)
    env_creator = lambda config: DMCEnv(
        env,
        task,
        from_pixels=from_pixels,
        height=height,
        width=width,
        frame_skip=frame_skip,
        channels_first=channels_first,
    )
    register_env(env_task_name, env_creator)
    DEFAULT_ENVS_REGISTRY[env_task_name] = env_creator

print(f">>> Number of registered envs: {len(BENCHMARKING)}")
# Out:
# acrobot-swingup
# acrobot-swingup_sparse
# ball_in_cup-catch
# cartpole-balance
# cartpole-balance_sparse
# cartpole-swingup
# cartpole-swingup_sparse
# cheetah-run
# finger-spin
# finger-turn_easy
# finger-turn_hard
# fish-upright
# fish-swim
# hopper-stand
# hopper-hop
# humanoid-stand
# humanoid-walk
# humanoid-run
# manipulator-bring_ball
# pendulum-swingup
# point_mass-easy
# reacher-easy
# reacher-hard
# swimmer-swimmer6
# swimmer-swimmer15
# walker-stand
# walker-walk
# walker-run
# >>> Number of registered envs: 28

# %% [markdown]
# ## Train agents on DMC Benchmark tasks

# %% [markdown]
# - DDPG
# - PPO
# - SAC

# %%
import copy

import ray.rllib.algorithms.ddpg as ddpg
import ray.rllib.algorithms.ppo as ppo
import ray.rllib.algorithms.sac as sac
from ray.rllib.utils.torch_utils import set_torch_seed

# %%
seeds = (0, 5, 10, 15, 20)
training_epoches = 100  # x horizon equals ~10^5 env steps
AGENT_SAMPLED_STEPS = 500000

config = {
    "env": None,
    "horizon": max_horizon,
    "num_workers": 8,
    "framework": "torch",
    "model": {
        "fcnet_hiddens": [64, 64],
        "fcnet_activation": "relu",
    },
    "num_gpus": 1,
    "evaluation_num_workers": 2,
    "evaluation_config": {
        "render_env": False,
    },
    "evaluation_interval": 10,
    "log_level": "ERROR",
}

# %% [markdown]
# ### DDPG

# %%
SKIP_ENVS = (
    "acrobot-swingup",
    "acrobot-swingup_sparse",
    "ball_in_cup-catch",
    "cartpole-balance",
    # "cartpole-balance_sparse",
    # "cartpole-swingup",
    # "cartpole-swingup_sparse",
    # "cheetah-run",
    # "finger-spin",
    # "finger-turn_easy",
    # "finger-turn_hard",
    # "fish-swim",
    # "fish-upright",
    # "hopper-hop",
    # "hopper-stand",
    # "humanoid-run",
    # "humanoid-stand",
    # "humanoid-walk",
    # "manipulator-bring_ball",
    # "point_mass-easy",
    # "reacher-easy",
    # "reacher-hard",
    # "swimmer-swimmer15",
    # "swimmer-swimmer6",
    # "walker-run",
    # "walker-stand",
    # "walker-walk",
    # 'pendulum-swingup',
)

LEARNING_ENVS = tuple(
    [f"{x}-{y}" for x, y in BENCHMARKING if f"{x}-{y}" not in SKIP_ENVS]
)

print(LEARNING_ENVS)
print(f">>> Number of learning envs: {len(LEARNING_ENVS)}")

SEEDS_ALREADY_DONE = 3
print(f">>> FIRST {SEEDS_ALREADY_DONE} SEEDS FOR {LEARNING_ENVS[0]} WILL BE SKIPEPD")

# %%
algo_name = "DDPG"

for env_task in LEARNING_ENVS:
    for seed in seeds:
        print(f"> Algo: {algo_name} | Training task: {env_task} | Seed: {seed}")

        if SEEDS_ALREADY_DONE:
            SEEDS_ALREADY_DONE -= 1
            print(
                f"> SKIPPING SEED ACCORDING TO THE RUN PARAMETER! (SEEDS_ALREADY_DONE={SEEDS_ALREADY_DONE+1})"
            )
            continue

        set_torch_seed(seed)
        config["env"] = env_task

        algo = ddpg.DDPG(config=config)

        algo._counters["num_agent_steps_sampled"] = 0
        while algo._counters["num_agent_steps_sampled"] < AGENT_SAMPLED_STEPS:
            algo.train()

        algo.evaluate()
        checkpoint_dir = algo.save(
            f"./checkpoints/{algo_name}/{env_task}_{seed}/final_checkpoint"
        )
        algo.stop()

# %% [markdown]
# ### PPO

# %%
SKIP_ENVS = (
    "acrobot-swingup",
    "acrobot-swingup_sparse",
    "ball_in_cup-catch",
    "cartpole-balance",
    "cartpole-balance_sparse",
    "cartpole-swingup",
    "cartpole-swingup_sparse",
    "cheetah-run",
    "finger-spin",
    "finger-turn_easy",
    "finger-turn_hard",
    "fish-upright",
    "fish-swim",
    "hopper-hop",
    "hopper-stand",
    # "humanoid-run",
    # "humanoid-stand",
    "humanoid-walk",
    "manipulator-bring_ball",
    "point_mass-easy",
    "pendulum-swingup",
    "reacher-easy",
    "reacher-hard",
    "swimmer-swimmer15",
    "swimmer-swimmer6",
    "walker-run",
    "walker-stand",
    "walker-walk",
)

LEARNING_ENVS = tuple(
    [f"{x}-{y}" for x, y in BENCHMARKING if f"{x}-{y}" not in SKIP_ENVS]
)

print(LEARNING_ENVS)
print(f">>> Number of learning envs: {len(LEARNING_ENVS)}")

SEEDS_ALREADY_DONE = 0
print(f">>> FIRST {SEEDS_ALREADY_DONE} SEEDS FOR {LEARNING_ENVS[0]} WILL BE SKIPEPD")
# Out:
# ('humanoid-stand', 'humanoid-run')
# >>> Number of learning envs: 2
# >>> FIRST 0 SEEDS FOR humanoid-stand WILL BE SKIPEPD

# %%
import ray.rllib.algorithms.ppo as ppo

algo_name = "PPO"

for env_task in LEARNING_ENVS:
    for seed in seeds:
        print(f"> Algo: {algo_name} | Training task: {env_task} | Seed: {seed}")

        if SEEDS_ALREADY_DONE:
            SEEDS_ALREADY_DONE -= 1
            print(
                f"> SKIPPING SEED ACCORDING TO THE RUN PARAMETER! (SEEDS_ALREADY_DONE={SEEDS_ALREADY_DONE+1})"
            )
            continue

        set_torch_seed(seed)
        config["env"] = env_task

        algo = ppo.PPO(config=config)

        algo._counters["num_agent_steps_sampled"] = 0
        while algo._counters["num_agent_steps_sampled"] < AGENT_SAMPLED_STEPS:
            algo.train()

        algo.evaluate()
        checkpoint_dir = algo.save(
            f"./checkpoints/{algo_name}/{env_task}_{seed}/final_checkpoint"
        )
        algo.stop()
# Out:
# 2023-05-19 09:03:25,318	WARNING ppo.py:351 -- `train_batch_size` (4000) cannot be achieved with your other settings (num_workers=8 num_envs_per_worker=1 rollout_fragment_length=200)! Auto-adjusting `rollout_fragment_length` to 500.
# 2023-05-19 09:03:25,319	INFO ppo.py:379 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# 2023-05-19 09:03:25,320	INFO algorithm.py:457 -- Current log_level is ERROR. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# > Algo: PPO | Training task: humanoid-stand | Seed: 0
# (RolloutWorker pid=1399901) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1399901) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1399901)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1399901) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1399901)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1399895) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1399895) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1399895)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1399895) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1399895)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1399896) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1399896) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1399896)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1399896) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1399896)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1399898) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1399898) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1399898)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1399898) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1399898)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1399899) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1399899) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1399899)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1399899) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1399899)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1399900) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1399900) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1399900)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1399900) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1399900)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1399902) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1399902) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1399902)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1399902) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1399902)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1399897) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1399897) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1399897)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1399897) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1399897)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1400121) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1400121) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1400121)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1400121) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1400121)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1400120) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1400120) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1400120)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1400120) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1400120)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# > Algo: PPO | Training task: humanoid-stand | Seed: 5
# (RolloutWorker pid=1401222) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1401222) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1401222)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1401222) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1401222)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1401220) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1401220) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1401220)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1401220) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1401220)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1401219) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1401219) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1401219)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1401219) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1401219)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1401221) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1401221) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1401221)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1401221) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1401221)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1401224) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1401224) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1401224)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1401224) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1401224)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1401223) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1401223) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1401223)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1401223) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1401223)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1401226) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1401226) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1401226)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1401226) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1401226)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1401225) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1401225) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1401225)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1401225) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1401225)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1401439) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1401439) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1401439)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1401439) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1401439)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1401440) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1401440) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1401440)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1401440) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1401440)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# > Algo: PPO | Training task: humanoid-stand | Seed: 10
# (RolloutWorker pid=1402204) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1402204) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1402204)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1402204) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1402204)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1402203) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1402203) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1402203)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1402203) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1402203)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1402247) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1402247) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1402247)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1402247) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1402247)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1402250) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1402250) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1402250)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1402250) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1402250)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1402248) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1402248) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1402248)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1402248) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1402248)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1402249) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1402249) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1402249)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1402249) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1402249)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1402255) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1402255) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1402255)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1402255) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1402255)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1402256) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1402256) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1402256)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1402256) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1402256)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1402426) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1402426) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1402426)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1402426) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1402426)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=
SEEDS_ALREADY_DONE = 4
print(f">>> FIRST {SEEDS_ALREADY_DONE} SEEDS FOR {LEARNING_ENVS[0]} WILL BE SKIPEPD")
# Out:
# ('hopper-hop', 'humanoid-stand', 'humanoid-walk')
# >>> Number of learning envs: 3
# >>> FIRST 4 SEEDS FOR hopper-hop WILL BE SKIPEPD

# %%
algo_name = "SAC"

for env_task in LEARNING_ENVS:
    for seed in seeds:
        print(f"> Algo: {algo_name} | Training task: {env_task} | Seed: {seed}")

        if SEEDS_ALREADY_DONE:
            SEEDS_ALREADY_DONE -= 1
            print(
                f"> SKIPPING SEED ACCORDING TO THE RUN PARAMETER! (SEEDS_ALREADY_DONE={SEEDS_ALREADY_DONE+1})"
            )
            continue

        set_torch_seed(seed)
        config["env"] = env_task

        algo = sac.SAC(config=config)

        algo._counters["num_agent_steps_sampled"] = 0
        while algo._counters["num_agent_steps_sampled"] < AGENT_SAMPLED_STEPS:
            algo.train()

        algo.evaluate()
        checkpoint_dir = algo.save(
            f"./checkpoints/{algo_name}/{env_task}_{seed}/final_checkpoint"
        )
        algo.stop()
# Out:
# 2023-05-15 00:26:35,826	INFO simple_q.py:307 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting `simple_optimizer=True` if this doesn't work for you.
# 2023-05-15 00:26:35,827	INFO algorithm.py:457 -- Current log_level is ERROR. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# > Algo: SAC | Training task: hopper-hop | Seed: 0
# > SKIPPING SEED ACCORDING TO THE RUN PARAMETER! (SEEDS_ALREADY_DONE=4)
# > Algo: SAC | Training task: hopper-hop | Seed: 5
# > SKIPPING SEED ACCORDING TO THE RUN PARAMETER! (SEEDS_ALREADY_DONE=3)
# > Algo: SAC | Training task: hopper-hop | Seed: 10
# > SKIPPING SEED ACCORDING TO THE RUN PARAMETER! (SEEDS_ALREADY_DONE=2)
# > Algo: SAC | Training task: hopper-hop | Seed: 15
# > SKIPPING SEED ACCORDING TO THE RUN PARAMETER! (SEEDS_ALREADY_DONE=1)
# > Algo: SAC | Training task: hopper-hop | Seed: 20
# (RolloutWorker pid=1516479) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1516479) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1516479)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1516479) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1516479)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1516480) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1516480) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1516480)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1516480) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1516480)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1516481) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1516481) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1516481)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1516481) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1516481)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1516485) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1516485) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1516485)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1516485) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1516485)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1516484) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1516484) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1516484)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1516484) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1516484)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1516483) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1516483) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1516483)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1516483) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1516483)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1516486) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1516486) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1516486)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1516486) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1516486)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1516482) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1516482) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1516482)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1516482) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1516482)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1516706) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1516706) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1516706)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1516706) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1516706)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1516705) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1516705) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1516705)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1516705) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1516705)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# > Algo: SAC | Training task: humanoid-stand | Seed: 0
# (RolloutWorker pid=1524347) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1524347) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1524347)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1524347) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1524347)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1524340) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1524340) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1524340)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1524340) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1524340)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1524341) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1524341) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1524341)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1524341) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1524341)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1524345) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1524345) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1524345)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1524345) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1524345)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1524342) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1524342) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1524342)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1524342) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1524342)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1524344) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1524344) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1524344)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1524344) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=1524344)   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# (RolloutWorker pid=1524346) /home/user/miniconda/lib/python3.10/site-packages/ray/rllib/env/wrappers/dm_control_wrapper.py:49: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# (RolloutWorker pid=1524346) Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (RolloutWorker pid=1524346)   dim = np.int(np.prod(s.shape))
# (RolloutWorker pid=1524346) /home/user/miniconda/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
# (RolloutWorker pid=